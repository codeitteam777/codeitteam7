# %% [markdown]
# PC 환경

# %%
# @title 라이브러리 사용 정리

import time
import json
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
# @title 로컬 경로 설정 및 JSON 파일 경로 수집

# Mac 로컬 환경의 데이터 기본 경로 설정
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
train_annotations_dir = os.path.join(base_data_dir, 'train_annotations') # train_annotations 폴더 경로

json_file_paths = [] # 모든 JSON 파일의 경로를 저장할 리스트

print(f"로컬 데이터 경로 설정 완료: {base_data_dir}")

start_time = time.time()

if os.path.exists(train_annotations_dir):
    for root, dirs, files in os.walk(train_annotations_dir):
        for file_name in files:
            if file_name.endswith('.json'):
                full_path = os.path.join(root, file_name)
                json_file_paths.append(full_path)

    end_time = time.time()

    print(f"'train_annotations'에서 발견된 총 JSON 파일 수: {len(json_file_paths)}개")
    print(f"경로 수집 완료 시간: {end_time - start_time:.2f}초")
    print(f"첫 번째 JSON 파일 경로 (예시): {json_file_paths[0]}")

else:
    print(f"로컬 경로를 찾을 수 없습니다. {train_annotations_dir}")
# Out:
# 로컬 데이터 경로 설정 완료: /Users/bellboi/data/ai05-level1-project
# 'train_annotations'에서 발견된 총 JSON 파일 수: 4526개
# 경로 수집 완료 시간: 0.29초
# 첫 번째 JSON 파일 경로 (예시): /Users/bellboi/data/ai05-level1-project/train_annotations/K-003483-025367-027777-035206_json/K-027777/K-003483-025367-027777-035206_0_2_0_2_75_000_200.json

# %%
# !pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.3.220-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (2.2.6)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Using cached matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (1.16.2)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.9.0-cp313-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.24.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.9 kB)
# Requirement already satisfied: psutil in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (7.1.1)
# Requirement already satisfied: polars in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from ultralytics) (1.34.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from polars->ultralytics) (1.34.0)
# Using cached ultralytics-8.3.220-py3-none-any.whl (1.1 MB)
# Using cached matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
# Using cached torch-2.9.0-cp313-none-macosx_11_0_arm64.whl (74.5 MB)
# Using cached torchvision-0.24.0-cp313-cp313-macosx_12_0_arm64.whl (1.9 MB)
# Using cached ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: torch, matplotlib, ultralytics-thop, torchvision, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ultralytics] [ultralytics]
# Successfully installed matplotlib-3.10.7 torch-2.9.0 torchvision-0.24.0 ultralytics-8.3.220 ultralytics-thop-2.0.17

# %%
q# @title JSON 경로에서 이미지 추출 및 YOLOv5 추론
import os
import json
import time
from ultralytics import YOLO # YOLOv5, YOLOv8 등을 지원하는 최신 ultralytics 패키지 사용

# ===============================================
# 1. 로컬 경로 설정 (이전 코드에서 가져옴)
# ===============================================
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
train_annotations_dir = os.path.join(base_data_dir, 'train_annotations')

json_file_paths = []

if os.path.exists(train_annotations_dir):
    for root, dirs, files in os.walk(train_annotations_dir):
        for file_name in files:
            if file_name.endswith('.json'):
                full_path = os.path.join(root, file_name)
                json_file_paths.append(full_path)

    if not json_file_paths:
        print("🚨 'train_annotations' 폴더에서 JSON 파일을 찾을 수 없습니다.")
        exit()

    print(f"'train_annotations'에서 발견된 총 JSON 파일 수: {len(json_file_paths)}개")
    first_json_path = json_file_paths[0]
    print(f"✅ 첫 번째 JSON 파일 경로 사용: {first_json_path}")
else:
    print(f"🚨 로컬 경로를 찾을 수 없습니다. {train_annotations_dir}")
    exit()

# ===============================================
# 2. JSON에서 이미지 경로 추정
# ===============================================
image_path = None
try:
    with open(first_json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # JSON 구조에서 이미지 파일 이름 추출 (데이터셋에 맞게 'file_name'을 가정)
    image_filename = data.get('file_name') or data.get('filename') or os.path.basename(first_json_path).replace('_json', '').replace('.json', '.jpg')

    # 이미지 파일 경로 추정 (JSON과 동일한 디렉토리 또는 'train_images' 폴더를 가정)
    # 🚨🚨 이 부분은 데이터셋의 실제 이미지 저장 구조에 따라 수정이 필요할 수 있습니다. 🚨🚨

    # 1) JSON과 같은 폴더에 이미지가 있다고 가정
    image_dir = os.path.dirname(first_json_path)
    base_name = os.path.splitext(image_filename)[0]

    # jpg, png 순서로 시도
    image_path = os.path.join(image_dir, base_name + '.jpg')
    if not os.path.exists(image_path):
        image_path = os.path.join(image_dir, base_name + '.png')

    # 2) 'train_images' 폴더에 이미지가 있다고 가정 (추가적인 확인)
    if not os.path.exists(image_path):
        image_path = os.path.join(base_data_dir, 'train_images', image_filename)
        # 이미지 파일 이름에 확장자가 없는 경우 .jpg 또는 .png 추가 시도
        if not os.path.exists(image_path) and '.' not in image_filename:
             image_path = os.path.join(base_data_dir, 'train_images', base_name + '.jpg')

    if not image_path or not os.path.exists(image_path):
        print(f"🚨 이미지 파일을 찾을 수 없습니다. 추정된 경로: {image_path}")
        exit()

except Exception as e:
    print(f"🚨 JSON 파일 처리 중 오류 발생: {e}")
    exit()

# ===============================================
# 3. YOLOv5 추론 실행
# ===============================================
print(f"\n🔎 최종 이미지 파일 경로: {image_path}")
print("📦 YOLOv5s 모델 로드 및 추론 시작...")
start_time = time.time()

# 가장 빠르고 가벼운 사전 훈련된 YOLOv5s 모델 로드
model = YOLO('yolov5s.pt')

# 추론 실행 및 결과 자동 저장
# save=True: 탐지 결과를 이미지에 그려 'runs/detect/yolov5_quick_test' 폴더에 저장합니다.
results = model.predict(
    source=image_path,
    conf=0.25, # 최소 신뢰도
    iou=0.7,   # IOU 임계값
    save=True,
    name='yolov5_quick_test' # 결과 폴더 이름 설정
)

end_time = time.time()
print(f"\n✅ YOLOv5 추론 완료! 소요 시간: {end_time - start_time:.2f}초")

# ===============================================
# 4. 결과 출력 및 저장 위치 안내
# ===============================================
for r in results:
    detected_count = len(r.boxes)
    print(f"\n✨ 탐지된 객체 수: {detected_count}개")

    # 결과가 저장된 폴더 경로
    save_dir = r.save_dir
    print(f"💾 결과 이미지 저장 위치: {save_dir}")
    print("📢 결과를 확인하려면 PyCharm의 프로젝트 구조 또는 Finder에서 위 폴더를 열어보세요.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/bellboi/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 'train_annotations'에서 발견된 총 JSON 파일 수: 4526개
# ✅ 첫 번째 JSON 파일 경로 사용: /Users/bellboi/data/ai05-level1-project/train_annotations/K-003483-025367-027777-035206_json/K-027777/K-003483-025367-027777-035206_0_2_0_2_75_000_200.json
# 🚨 이미지 파일을 찾을 수 없습니다. 추정된 경로: /Users/bellboi/data/ai05-level1-project/train_images/K-003483-025367-027777-035206_0_2_0_2_75_000_200.jpg
#
# 🔎 최종 이미지 파일 경로: /Users/bellboi/data/ai05-level1-project/train_images/K-003483-025367-027777-035206_0_2_0_2_75_000_200.jpg
# 📦 YOLOv5s 모델 로드 및 추론 시작...
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5su.pt to 'yolov5su.pt': 100% ━━━━━━━━━━━━ 17.7MB 34.4MB/s 0.5s0.5s<0.0s
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 83
#      79 model = YOLO('yolov5s.pt')
#      81 # 추론 실행 및 결과 자동 저장
#      82 # save=True: 탐지 결과를 이미지에 그려 'runs/detect/yolov5_quick_test' 폴더에 저장합니다.
# ---> 83 results = model.predict(
#      84     source=image_path,
#      85     conf=0.25, # 최소 신뢰도
#      86     iou=0.7,   # IOU 임계값
#      87     save=True,
#      88     name='yolov5_quick_test' # 결과 폴더 이름 설정
#      89 )
#      91 end_time = time.time()
#      92 print(f"\n✅ YOLOv5 추론 완료! 소요 시간: {end_time - start_time:.2f}초")
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/predictor.py:230, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     228     return self.stream_inference(source, model, *args, **kwargs)
#     229 else:
# --> 230     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/predictor.py:307, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     303     self.setup_model(model)
#     305 with self._lock:  # for thread-safe inference
#     306     # Setup source every time predict is called
# --> 307     self.setup_source(source if source is not None else self.args.source)
#     309     # Check if save_dir/ label file exists
#     310     if self.args.save or self.args.save_txt:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/predictor.py:262, in BasePredictor.setup_source(self, source)
#     254 """
#     255 Set up source and inference mode.
#     256
#    (...)
#     259         Source for inference.
#     260 """
#     261 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
# --> 262 self.dataset = load_inference_source(
#     263     source=source,
#     264     batch=self.args.batch,
#     265     vid_stride=self.args.vid_stride,
#     266     buffer=self.args.stream_buffer,
#     267     channels=getattr(self.model, "ch", 3),
#     268 )
#     269 self.source_type = self.dataset.source_type
#     270 long_sequence = (
#     271     self.source_type.stream
#     272     or self.source_type.screenshot
#     273     or len(self.dataset) > 1000  # many images
#     274     or any(getattr(self.dataset, "video_flag", [False]))
#     275 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/build.py:424, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     422     dataset = LoadPilAndNumpy(source, channels=channels)
#     423 else:
# --> 424     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     426 # Attach source types to the dataset
#     427 setattr(dataset, "source_type", source_type)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/loaders.py:376, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     374         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     375     else:
# --> 376         raise FileNotFoundError(f"{p} does not exist")
#     378 # Define files as images or videos
#     379 images, videos = [], []
#
# FileNotFoundError: /Users/bellboi/data/ai05-level1-project/train_images/K-003483-025367-027777-035206_0_2_0_2_75_000_200.jpg does not exist

# %%
# @title JSON 경로에서 이미지 추출 및 YOLOv5 추론 - 수정된 이미지 경로 탐색 로직
# (앞부분 import 및 1. 로컬 경로 설정 코드는 동일하게 유지합니다.)

# ===============================================
# 2. JSON에서 이미지 경로 추정 (수정)
# ===============================================
print(f"\n✅ 첫 번째 JSON 파일 경로 사용: {first_json_path}")
image_path = None
try:
    # 1. JSON 파일 로드 및 이미지 파일 이름 추출
    with open(first_json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # JSON 구조에서 이미지 파일 이름 추출 ('file_name'을 가정)
    image_filename = data.get('file_name') or data.get('filename')

    # JSON 파일 이름 자체를 이미지 파일 이름으로 가정 (확장자만 다름)
    if not image_filename:
        # 'K-003483-025367-027777-035206_0_2_0_2_75_000_200.json' -> 'K-003483-025367-027777-035206_0_2_0_2_75_000_200'
        base_name = os.path.basename(first_json_path).replace('_json', '').replace('.json', '')
        image_filename = base_name

    # 2. 경로 탐색 시도 리스트
    # JSON 파일의 이름 (확장자 제외)
    base_name = os.path.splitext(image_filename)[0]

    # 탐색할 폴더 경로 리스트 (JSON 파일 경로를 기준으로 탐색)
    json_dir = os.path.dirname(first_json_path)
    json_parent_dir = os.path.dirname(json_dir) # '/.../K-003483-025367-027777-035206_json/K-027777'의 부모: '/.../K-003483-025367-027777-035206_json'

    search_dirs = [
        json_dir,         # 1. JSON 파일과 같은 폴더 (예: K-027777)
        json_parent_dir,  # 2. JSON 파일의 부모 폴더 (예: K-003483-...)
        os.path.join(base_data_dir, 'train_images') # 3. 기존에 시도했던 'train_images' (보조)
    ]

    # 3. 경로 탐색
    for directory in search_dirs:
        # .jpg, .png 확장자 시도
        for ext in ['.jpg', '.png']:
            current_path = os.path.join(directory, base_name + ext)
            if os.path.exists(current_path):
                image_path = current_path
                print(f"✅ 이미지 파일을 찾았습니다! 경로: {image_path}")
                break
        if image_path:
            break

    if not image_path:
        print(f"🚨 이미지 파일을 찾을 수 없습니다. 시도한 파일 이름: {base_name}.(jpg/png)")
        exit()

except Exception as e:
    print(f"🚨 JSON 파일 처리 중 오류 발생: {e}")
    exit()

# (3. YOLOv5 추론 실행 코드는 동일하게 유지합니다.)
# ===============================================
# 3. YOLOv5 추론 실행
# ===============================================
# ... (이하 코드는 동일)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 # @title JSON 경로에서 이미지 추출 및 YOLOv5 추론 - 수정된 이미지 경로 탐색 로직
#       2 # (앞부분 import 및 1. 로컬 경로 설정 코드는 동일하게 유지합니다.)
#       3
#       4 # ===============================================
#       5 # 2. JSON에서 이미지 경로 추정 (수정)
#       6 # ===============================================
# ----> 7 print(f"\n✅ 첫 번째 JSON 파일 경로 사용: {first_json_path}")
#       8 image_path = None
#       9 try:
#      10     # 1. JSON 파일 로드 및 이미지 파일 이름 추출
#
# NameError: name 'first_json_path' is not defined

# %%
# @title JSON 경로에서 이미지 추출 및 YOLOv5 추론 - 최종 버전 (경로 확정)
import os
import json
import time
from ultralytics import YOLO # Conda 환경에 설치된 ultralytics 사용

# ===============================================
# 1. 로컬 경로 설정 (이전 코드에서 가져옴)
# ===============================================
# Mac 로컬 환경의 데이터 기본 경로 설정
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
train_annotations_dir = os.path.join(base_data_dir, 'train_annotations')
train_images_dir = os.path.join(base_data_dir, 'train_images') # 이미지 폴더 경로 추가

json_file_paths = []
# ... (JSON 경로 수집 로직은 이전과 동일)
if os.path.exists(train_annotations_dir):
    start_time = time.time()
    for root, dirs, files in os.walk(train_annotations_dir):
        for file_name in files:
            if file_name.endswith('.json'):
                json_file_paths.append(os.path.join(root, file_name))

    if not json_file_paths:
        print("🚨 'train_annotations' 폴더에서 JSON 파일을 찾을 수 없습니다.")
        exit()

    print(f"'train_annotations'에서 발견된 총 JSON 파일 수: {len(json_file_paths)}개")
    print(f"경로 수집 완료 시간: {time.time() - start_time:.2f}초")
    first_json_path = json_file_paths[0]
    print(f"✅ 첫 번째 JSON 파일 경로 사용: {first_json_path}")
else:
    print(f"🚨 로컬 경로를 찾을 수 없습니다. {train_annotations_dir}")
    exit()

# ===============================================
# 2. JSON에서 이미지 경로 추정 (구조 확정)
# ===============================================
image_path = None
try:
    # 1. JSON 파일 이름 추출 (확장자 제거)
    json_filename = os.path.basename(first_json_path)
    # 예: 'K-001900-016548-01811...200.json'

    # 2. 이미지 파일 이름 추정
    # JSON 파일 이름의 확장자(.json)를 제거하고 이미지 확장자(.png)를 붙입니다.
    # 제공된 이미지 파일은 모두 .png 확장자를 사용하고 있습니다.
    base_name_without_ext = os.path.splitext(json_filename)[0].replace('_json', '')
    image_filename = base_name_without_ext + '.png' # PNG 확정

    # 3. 최종 이미지 경로 생성 (train_images 폴더 사용)
    image_path = os.path.join(train_images_dir, image_filename)

    if not os.path.exists(image_path):
        # 만약 .png가 아니라 .jpg일 가능성도 있다면 (보조 확인)
        image_filename_jpg = base_name_without_ext + '.jpg'
        image_path = os.path.join(train_images_dir, image_filename_jpg)

        if not os.path.exists(image_path):
            print(f"🚨 이미지 파일을 찾을 수 없습니다.")
            print(f"시도한 경로 (.png): {os.path.join(train_images_dir, base_name_without_ext + '.png')}")
            print(f"시도한 경로 (.jpg): {os.path.join(train_images_dir, base_name_without_ext + '.jpg')}")
            exit()

    print(f"\n🔎 최종 이미지 파일 경로: {image_path}")

except Exception as e:
    print(f"🚨 JSON 파일 처리 중 오류 발생: {e}")
    exit()

# ===============================================
# 3. YOLOv5 추론 실행
# ===============================================
print("📦 YOLOv5s 모델 로드 및 추론 시작...")
start_time = time.time()

# 가장 빠르고 가벼운 사전 훈련된 YOLOv5s 모델 로드
model = YOLO('yolov5s.pt')

# 추론 실행 및 결과 자동 저장
# save=True: 탐지 결과를 이미지에 그려 'runs/detect/yolov5_quick_test' 폴더에 저장합니다.
results = model.predict(
    source=image_path,
    conf=0.25, # 최소 신뢰도
    iou=0.7,   # IOU 임계값
    save=True,
    name='yolov5_quick_test' # 결과 폴더 이름 설정
)

end_time = time.time()
print(f"\n✅ YOLOv5 추론 완료! 소요 시간: {end_time - start_time:.2f}초")

# ===============================================
# 4. 결과 출력 및 저장 위치 안내
# ===============================================
for r in results:
    detected_count = len(r.boxes)
    print(f"\n✨ 탐지된 객체 수: {detected_count}개")

    save_dir = r.save_dir
    print(f"💾 결과 이미지 저장 위치: {save_dir}")
    print("📢 결과를 확인하려면 PyCharm의 프로젝트 구조 또는 Finder에서 위 폴더를 열어보세요.")
# Out:
# 'train_annotations'에서 발견된 총 JSON 파일 수: 4526개
# 경로 수집 완료 시간: 0.24초
# ✅ 첫 번째 JSON 파일 경로 사용: /Users/bellboi/data/ai05-level1-project/train_annotations/K-003483-025367-027777-035206_json/K-027777/K-003483-025367-027777-035206_0_2_0_2_75_000_200.json
#
# 🔎 최종 이미지 파일 경로: /Users/bellboi/data/ai05-level1-project/train_images/K-003483-025367-027777-035206_0_2_0_2_75_000_200.png
# 📦 YOLOv5s 모델 로드 및 추론 시작...
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# image 1/1 /Users/bellboi/data/ai05-level1-project/train_images/K-003483-025367-027777-035206_0_2_0_2_75_000_200.png: 640x512 1 sports ball, 1 remote, 141.3ms
# Speed: 4.2ms preprocess, 141.3ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /Users/bellboi/code/codeitteam7/runs/detect/yolov5_quick_test
#
# ✅ YOLOv5 추론 완료! 소요 시간: 0.31초
#
# ✨ 탐지된 객체 수: 2개
# 💾 결과 이미지 저장 위치: /Users/bellboi/code/codeitteam7/runs/detect/yolov5_quick_test
# 📢 결과를 확인하려면 PyCharm의 프로젝트 구조 또는 Finder에서 위 폴더를 열어보세요.

# %%
# @title JSON을 YOLO 포맷 TXT로 변환
# 주의: 이 코드는 JSON 구조에 따라 수정이 필요할 수 있습니다.

import os
import json
import time
from tqdm import tqdm # 진행 상황을 보기 쉽게 하기 위해 tqdm 사용

# 1. 경로 설정 (이전 코드에서 재사용)
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
train_annotations_dir = os.path.join(base_data_dir, 'train_annotations')
train_images_dir = os.path.join(base_data_dir, 'train_images')

# YOLO 라벨을 저장할 새로운 폴더 생성
yolo_labels_dir = os.path.join(base_data_dir, 'train_labels')
os.makedirs(yolo_labels_dir, exist_ok=True)
print(f"YOLO 라벨 저장 폴더 생성: {yolo_labels_dir}")

# 이전 단계에서 수집된 전체 JSON 파일 경로 리스트 (4526개)를 사용한다고 가정
# json_file_paths = ...

# ===============================================
# 2. 변환 함수 (COCO 포맷 기준)
# ===============================================
def json_to_yolo_txt(json_path, image_width, image_height):
    """
    JSON 파일 경로를 받아 YOLO 포맷의 TXT 문자열을 반환합니다.
    (x_min, y_min, w, h) -> (center_x, center_y, w, h) 정규화
    """
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    yolo_lines = []

    # 이 부분은 데이터셋의 JSON 구조에 따라 반드시 수정해야 합니다.
    # 예시: COCO 스타일의 'annotations' 리스트를 가정
    annotations = data.get('annotations', [])

    for anno in annotations:
        try:
            # 1. 클래스 ID (데이터셋의 ID에 맞게 조정해야 합니다)
            class_id = anno['category_id']

            # 2. 바운딩 박스 (x_min, y_min, w, h 형태를 가정)
            bbox = anno['bbox'] # [x, y, w, h]
            x, y, w, h = bbox

            # 3. YOLO 포맷으로 변환 및 정규화
            center_x = (x + w / 2) / image_width
            center_y = (y + h / 2) / image_height
            norm_w = w / image_width
            norm_h = h / image_height

            # 4. YOLO 라인 생성: [class_id] [center_x] [center_y] [w] [h]
            line = f"{class_id} {center_x:.6f} {center_y:.6f} {norm_w:.6f} {norm_h:.6f}"
            yolo_lines.append(line)
        except KeyError as e:
            # 'annotations' 키 아래에 'category_id'나 'bbox'가 없을 경우
            print(f"경고: {json_path}에서 필수 키({e})를 찾을 수 없습니다. 스킵합니다.")
            continue

    return "\n".join(yolo_lines)

# ===============================================
# 3. 전체 JSON 파일 변환 실행
# ===============================================
print(f"\n총 {len(json_file_paths)}개의 JSON 파일을 YOLO TXT 포맷으로 변환 시작...")
start_time = time.time()

# 이미지 크기 정보 (임시): 현재 데이터셋의 이미지 크기를 모르므로, 첫 번째 이미지의 크기를 로드합니다.
# 실제로는 JSON 파일 안에 이미지 크기가 포함되어 있는 경우가 많습니다.
# 만약 YOLO 추론에서 사용된 640x512가 이미지 크기라면 이를 사용해야 합니다.
# 여기서는 실제 이미지 파일에서 크기를 얻어오겠습니다.
import cv2

def get_image_dimensions(image_filename):
    """train_images 폴더에서 파일 크기를 읽어옵니다."""
    base_name_without_ext = os.path.splitext(image_filename)[0].replace('_json', '').replace('.json', '')

    # PNG 파일을 먼저 시도
    img_path_png = os.path.join(train_images_dir, base_name_without_ext + '.png')
    if os.path.exists(img_path_png):
        img = cv2.imread(img_path_png)
        if img is not None:
             return img.shape[1], img.shape[0] # (width, height)

    # JPG 파일을 시도
    img_path_jpg = os.path.join(train_images_dir, base_name_without_ext + '.jpg')
    if os.path.exists(img_path_jpg):
        img = cv2.imread(img_path_jpg)
        if img is not None:
             return img.shape[1], img.shape[0] # (width, height)

    return None, None


for json_path in tqdm(json_file_paths, desc="변환 중"):
    # 1. 이미지 크기 얻기 (정규화를 위해 필요)
    json_filename = os.path.basename(json_path)
    img_w, img_h = get_image_dimensions(json_filename)

    if img_w is None or img_h is None:
        # 이미지 파일을 찾지 못하면 해당 JSON은 스킵
        continue

    # 2. YOLO TXT 내용 생성
    yolo_content = json_to_yolo_txt(json_path, img_w, img_h)

    # 3. TXT 파일로 저장
    # JSON 파일명과 동일하게 만들고 확장자만 .txt로 변경
    base_filename = os.path.splitext(os.path.basename(json_path))[0]
    txt_filename = base_filename.replace('_json', '') + '.txt'
    txt_path = os.path.join(yolo_labels_dir, txt_filename)

    with open(txt_path, 'w', encoding='utf-8') as f:
        f.write(yolo_content)

end_time = time.time()
print(f"\n✅ 전체 JSON 파일 변환 완료! 소요 시간: {end_time - start_time:.2f}초")
print(f"저장 위치 예시: {os.path.join(yolo_labels_dir, 'K-003483-025367-027777-035206_0_2_0_2_75_000_200.txt')}")
# Out:
# YOLO 라벨 저장 폴더 생성: /Users/bellboi/data/ai05-level1-project/train_labels
#
# 총 4526개의 JSON 파일을 YOLO TXT 포맷으로 변환 시작...
# 변환 중: 100%|██████████| 4526/4526 [01:35<00:00, 47.51it/s]
# ✅ 전체 JSON 파일 변환 완료! 소요 시간: 95.31초
# 저장 위치 예시: /Users/bellboi/data/ai05-level1-project/train_labels/K-003483-025367-027777-035206_0_2_0_2_75_000_200.txt

# %%
# @title YOLOv8 미니 학습 실행 (PyCharm)
import os
from ultralytics import YOLO

# 1. 경로 및 설정 파일 확인
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
data_yaml_path = os.path.join(os.getcwd(), 'ai05_pill_data.yaml') # 현재 스크립트가 있는 폴더에 있다고 가정

# train_images 폴더에 이미지를, train_labels 폴더에 TXT 라벨을 복사/이동했다고 가정합니다.
# 만약 라벨 폴더 이름을 train_labels 대신 labels로 사용하려면 data.yaml도 수정해야 합니다.

print(f"데이터 설정 파일 경로: {data_yaml_path}")

# 2. YOLOv8n 모델 로드 (가장 빠르고 가벼움)
# 'n'은 nano를 의미하며, 가장 가볍고 빠르게 학습/추론이 가능합니다.
model = YOLO('yolov8n.pt')

print("🚀 YOLOv8 모델로 알약 데이터 파인튜닝 시작 (최소 5 에폭)")

# 3. 학습 실행
# project/name: 결과가 저장될 폴더 경로를 지정합니다.
# data: 위에서 생성한 설정 파일 경로
# epochs: 학습 횟수 (빠른 확인을 위해 5회 설정)
# imgsz: 이미지 크기 (기본값인 640 사용)
# batch: 배치 크기 (GPU 메모리가 부족하면 4 또는 2로 줄이세요)
results = model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=8,
    project='yolo_quick_run',
    name='pill_detection_nano_v1'
)

print("\n✅ YOLOv8 미니 학습 완료!")
print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_v1')}")
print("📢 'runs/detect/pill_detection_nano_v1' 폴더에서 결과 그래프와 학습된 모델을 확인할 수 있습니다.")
# Out:
# 데이터 설정 파일 경로: /Users/bellboi/code/codeitteam7/ai05_pill_data.yaml
# 🚀 YOLOv8 모델로 알약 데이터 파인튜닝 시작 (최소 5 에폭)
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pill_detection_nano_v13, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_v13, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.1 ms, read: 985.2±206.9 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels... 1489 images, 0 backgrounds, 1489 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 680.9it/s 2.2s0.1s
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-010224-016551-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-018110-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-019607-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-021771_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-021771_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-021771_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-024850_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-024850_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-024850_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16547 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021026-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-021771-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16547 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-024850-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-027926-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029345-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-029451-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-031705-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33207 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016548-033009-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-018110-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 18109 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 19606 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-019607-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-021771_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-021771_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-021771_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-024850_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-024850_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-024850_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021026-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 44198 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 29450 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 21770 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-021771-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 24849 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-024850-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-033208_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-033208_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 1899 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-033208_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-044199_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-044199_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-001900-016551-027926-044199_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# ...
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-006563-016551-033878_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-006563-016551-033878_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-006563-016551-033878_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16547 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 29344 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 31704 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016548-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 33008 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029345_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029345_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029345_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029451_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029451_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-029451_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-031705_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-031705_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-031705_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-033009_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-033009_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-010221-016551-033009_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 16550 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-021026_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-021026_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 21025 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-021026_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-027926_0_2_0_2_70_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-027926_0_2_0_2_75_000_200.png: ignoring corrupt image/label: Label class 3543 exceeds dataset class count 2. Possible class labels are 0-1
# train: /Users/bellboi/data/ai05-level1-project/images/K-003544-012247-016548-027926_0_2_0_2_90_000_200.png: ignoring corrupt image/label: Label class 12246 exceeds dataset class count 2. Possible class labels are 0-1
# train: New cache created: /Users/bellboi/data/ai05-level1-project/labels.cache
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 26
#      18 print("🚀 YOLOv8 모델로 알약 데이터 파인튜닝 시작 (최소 5 에폭)")
#      20 # 3. 학습 실행
#      21 # project/name: 결과가 저장될 폴더 경로를 지정합니다.
#      22 # data: 위에서 생성한 설정 파일 경로
#      23 # epochs: 학습 횟수 (빠른 확인을 위해 5회 설정)
#      24 # imgsz: 이미지 크기 (기본값인 640 사용)
#      25 # batch: 배치 크기 (GPU 메모리가 부족하면 4 또는 2로 줄이세요)
# ---> 26 results = model.train(
#      27     data=data_yaml_path,
#      28     epochs=5,
#      29     imgsz=640,
#      30     batch=8,
#      31     project='yolo_quick_run',
#      32     name='pill_detection_nano_v1'
#      33 )
#      35 print("\n✅ YOLOv8 미니 학습 완료!")
#      36 print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_v1')}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:238, in BaseTrainer.train(self)
#     235         ddp_cleanup(self, str(file))
#     237 else:
# --> 238     self._do_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:359, in BaseTrainer._do_train(self)
#     357 if self.world_size > 1:
#     358     self._setup_ddp()
# --> 359 self._setup_train()
#     361 nb = len(self.train_loader)  # number of batches
#     362 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:318, in BaseTrainer._setup_train(self)
#     316 # Dataloaders
#     317 batch_size = self.batch_size // max(self.world_size, 1)
# --> 318 self.train_loader = self.get_dataloader(
#     319     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     320 )
#     321 # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
#     322 self.test_loader = self.get_dataloader(
#     323     self.data.get("val") or self.data.get("test"),
#     324     batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     325     rank=LOCAL_RANK,
#     326     mode="val",
#     327 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/models/yolo/detect/train.py:97, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      95 assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      96 with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 97     dataset = self.build_dataset(dataset_path, mode, batch_size)
#      98 shuffle = mode == "train"
#      99 if getattr(dataset, "rect", False) and shuffle:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/models/yolo/detect/train.py:80, in DetectionTrainer.build_dataset(self, img_path, mode, batch)
#      68 """
#      69 Build YOLO Dataset for training or validation.
#      70
#    (...)
#      77     (Dataset): YOLO dataset object configured for the specified mode.
#      78 """
#      79 gs = max(int(unwrap_model(self.model).stride.max() if self.model else 0), 32)
# ---> 80 return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/build.py:233, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     231 """Build and return a YOLO dataset based on configuration parameters."""
#     232 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 233 return dataset(
#     234     img_path=img_path,
#     235     imgsz=cfg.imgsz,
#     236     batch_size=batch,
#     237     augment=mode == "train",  # augmentation
#     238     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     239     rect=cfg.rect or rect,  # rectangular batches
#     240     cache=cfg.cache or None,
#     241     single_cls=cfg.single_cls or False,
#     242     stride=stride,
#     243     pad=0.0 if mode == "train" else 0.5,
#     244     prefix=colorstr(f"{mode}: "),
#     245     task=cfg.task,
#     246     classes=cfg.classes,
#     247     data=data,
#     248     fraction=cfg.fraction if mode == "train" else 1.0,
#     249 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/dataset.py:90, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      88 self.data = data
#      89 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 90 super().__init__(*args, channels=self.data.get("channels", 3), **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/base.py:118, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction, channels)
#     116 self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR
#     117 self.im_files = self.get_img_files(self.img_path)
# --> 118 self.labels = self.get_labels()
#     119 self.update_labels(include_class=classes)  # single_cls and include_class
#     120 self.ni = len(self.labels)  # number of images
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/data/dataset.py:190, in YOLODataset.get_labels(self)
#     188 labels = cache["labels"]
#     189 if not labels:
# --> 190     raise RuntimeError(
#     191         f"No valid images found in {cache_path}. Images with incorrectly formatted labels are ignored. {HELP_URL}"
#     192     )
#     193 self.im_files = [lb["im_file"] for lb in labels]  # update im_files
#     195 # Check if the dataset is all boxes or all segments
#
# RuntimeError: No valid images found in /Users/bellboi/data/ai05-level1-project/labels.cache. Images with incorrectly formatted labels are ignored. See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
# 이전 변환 코드의 일부 (KeyError를 방지하기 위해 try/except로 묶여 있었음)
class_id = anno['category_id'] # JSON의 category_id를 그대로 사용
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 이전 변환 코드의 일부 (KeyError를 방지하기 위해 try/except로 묶여 있었음)
# ----> 2 class_id = anno['category_id'] # JSON의 category_id를 그대로 사용
#
# NameError: name 'anno' is not defined

# %%
# @title JSON을 YOLO 포맷 TXT로 변환 - 클래스 0으로 통일 (Test용)

# (이전 코드에서 json_to_yolo_txt 함수만 아래와 같이 수정합니다.)

def json_to_yolo_txt(json_path, image_width, image_height):
    # ... (파일 로드 부분은 동일)

    yolo_lines = []
    annotations = data.get('annotations', [])

    for anno in annotations:
        try:
            # 1. 클래스 ID: 임시로 무조건 0으로 설정하여 유효성 검사 통과 시도
            class_id = 0

            # 2. 바운딩 박스 (x_min, y_min, w, h 형태를 가정)
            bbox = anno['bbox'] # [x, y, w, h]
            x, y, w, h = bbox

            # 3. YOLO 포맷으로 변환 및 정규화
            center_x = (x + w / 2) / image_width
            center_y = (y + h / 2) / image_height
            norm_w = w / image_width
            norm_h = h / image_height

            # 4. 정규화된 값이 0~1 사이에 있는지 확인 (매우 중요)
            if not all(0 <= val <= 1.0 for val in [center_x, center_y, norm_w, norm_h]):
                 print(f"경고: {json_path}의 바운딩 박스 값이 0~1 범위를 벗어납니다. 스킵합니다.")
                 continue

            line = f"{class_id} {center_x:.6f} {center_y:.6f} {norm_w:.6f} {norm_h:.6f}"
            yolo_lines.append(line)
        except KeyError as e:
            # annotations, bbox, category_id 등의 키가 없는 경우
            continue # 해당 객체는 스킵하고 다음 객체로 진행

    return "\n".join(yolo_lines)

# %%
# @title JSON을 YOLO 포맷 TXT로 변환 - 클래스 0으로 통일 (Test용) - 통합 코드
import os
import json
import time
from tqdm import tqdm
import cv2 # 이미지 크기를 읽기 위해 필요

# ===============================================
# 1. 경로 설정 (이전 코드에서 재사용)
# ===============================================
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
train_annotations_dir = os.path.join(base_data_dir, 'train_annotations')
images_dir = os.path.join(base_data_dir, 'images') # 이름 변경된 'images' 폴더 사용
labels_dir = os.path.join(base_data_dir, 'labels') # 이름 변경된 'labels' 폴더 사용

os.makedirs(labels_dir, exist_ok=True)
print(f"YOLO 라벨 저장 폴더: {labels_dir}")

# JSON 파일 경로 수집 (이전 코드와 동일하게 JSON 경로를 먼저 채웁니다)
json_file_paths = []
if os.path.exists(train_annotations_dir):
    for root, dirs, files in os.walk(train_annotations_dir):
        for file_name in files:
            if file_name.endswith('.json'):
                json_file_paths.append(os.path.join(root, file_name))
    print(f"총 JSON 파일 수: {len(json_file_paths)}개")
else:
    print(f"🚨 JSON 경로를 찾을 수 없습니다: {train_annotations_dir}")
    exit()

# ===============================================
# 2. 이미지 크기 얻는 함수 (get_image_dimensions)
# ===============================================
def get_image_dimensions(json_filename):
    """images 폴더에서 파일 크기를 읽어옵니다."""
    # JSON 파일명에서 .json 확장자를 제거하고 이미지 파일명 추정
    base_name_without_ext = os.path.splitext(os.path.basename(json_filename))[0].replace('_json', '')

    # PNG 파일을 먼저 시도
    img_path_png = os.path.join(images_dir, base_name_without_ext + '.png')
    if os.path.exists(img_path_png):
        img = cv2.imread(img_path_png)
        if img is not None:
             return img.shape[1], img.shape[0] # (width, height)

    # JPG 파일을 시도
    img_path_jpg = os.path.join(images_dir, base_name_without_ext + '.jpg')
    if os.path.exists(img_path_jpg):
        img = cv2.imread(img_path_jpg)
        if img is not None:
             return img.shape[1], img.shape[0] # (width, height)

    return None, None

# ===============================================
# 3. 변환 함수 (클래스 0으로 통일, 바운딩 박스 범위 체크 추가)
# ===============================================
def json_to_yolo_txt(json_path, image_width, image_height):
    """JSON을 YOLO TXT로 변환 (클래스 ID는 0으로 고정)"""
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    yolo_lines = []
    # 데이터셋의 구조가 COCO와 유사하게 'annotations' 키를 사용한다고 가정
    annotations = data.get('annotations', [])

    for anno in annotations:
        try:
            # 1. 클래스 ID: 빠른 테스트를 위해 0으로 고정
            class_id = 0

            # 2. 바운딩 박스 (x_min, y_min, w, h 형태를 가정)
            bbox = anno.get('bbox') # [x, y, w, h]
            if not bbox or len(bbox) != 4: continue # 바운딩 박스 정보가 없으면 스킵

            x, y, w, h = bbox

            # 3. YOLO 포맷으로 변환 및 정규화
            center_x = (x + w / 2) / image_width
            center_y = (y + h / 2) / image_height
            norm_w = w / image_width
            norm_h = h / image_height

            # 4. 정규화된 값이 유효한지 확인 (0.0~1.0 범위를 벗어나면 YOLO에서 무시됨)
            if not all(0 <= val <= 1.0 for val in [center_x, center_y, norm_w, norm_h]):
                 # 값이 범위를 벗어난다면 해당 바운딩 박스는 버립니다.
                 continue

            line = f"{class_id} {center_x:.6f} {center_y:.6f} {norm_w:.6f} {norm_h:.6f}"
            yolo_lines.append(line)
        except Exception:
            # 데이터 구조가 다른 객체는 무시합니다.
            continue

    return "\n".join(yolo_lines)

## @title JSON을 YOLO 포맷 TXT로 변환 - 오타 수정 후 재실행

# (앞부분의 import, 함수 정의 등은 모두 동일하게 유지합니다.)

# ===============================================
# 4. 전체 JSON 파일 변환 실행 (메인 루프)
# ===============================================
print(f"\n총 {len(json_file_paths)}개의 JSON 파일을 YOLO TXT 포맷으로 변환 시작...")
start_time = time.time()

for json_path in tqdm(json_file_paths, desc="변환 중"):

    # 1. 이미지 크기 얻기
    json_filename = os.path.basename(json_path)
    img_w, img_h = get_image_dimensions(json_filename)

    if img_w is None or img_h is None:
        continue # 이미지 파일을 찾지 못하면 스킵

    # 2. YOLO TXT 내용 생성
    yolo_content = json_to_yolo_txt(json_path, img_w, img_h)

    # 3. TXT 파일로 저장
    base_filename = os.path.splitext(os.path.basename(json_path))[0] # 여기서 base_filename 정의

    # 🚨🚨 오타 수정 부분 🚨🚨
    txt_filename = base_filename.replace('_json', '') + '.txt' # 'base_' 대신 'base_filename' 사용

    txt_path = os.path.join(labels_dir, txt_filename)

    with open(txt_path, 'w', encoding='utf-8') as f:
        f.write(yolo_content)

end_time = time.time()
print(f"\n✅ 전체 JSON 파일 변환 완료! 소요 시간: {end_time - start_time:.2f}초")
# Out:
# YOLO 라벨 저장 폴더: /Users/bellboi/data/ai05-level1-project/labels
# 총 JSON 파일 수: 4526개
#
# 총 4526개의 JSON 파일을 YOLO TXT 포맷으로 변환 시작...
# 변환 중: 100%|██████████| 4526/4526 [01:28<00:00, 51.32it/s]
# ✅ 전체 JSON 파일 변환 완료! 소요 시간: 88.19초

# %%
# @title YOLOv8 미니 학습 실행 (최종)
import os
from ultralytics import YOLO
import torch # GPU 사용 가능 여부 확인용

# GPU 사용 가능 여부 확인 (Apple M2는 Metal Performance Shaders(MPS)를 사용합니다)
if torch.backends.mps.is_available():
    device = 'mps'
    print("✅ Apple M2 GPU (MPS) 사용 가능! 학습 속도가 빠를 수 있습니다.")
elif torch.cuda.is_available():
    device = 'cuda'
    print("✅ NVIDIA GPU (CUDA) 사용 가능!")
else:
    device = 'cpu'
    print("⚠️ CPU 모드로 학습을 시작합니다.")

# 1. 경로 및 설정 파일 확인
base_data_dir = '/Users/bellboi/data/ai05-level1-project'
# ai05_pill_data.yaml 파일이 현재 실행 폴더에 있다고 가정합니다.
data_yaml_path = os.path.join(os.getcwd(), 'ai05_pill_data.yaml')

print(f"\n데이터 설정 파일 경로: {data_yaml_path}")
print("🚀 YOLOv8 모델로 알약 데이터 파인튜닝 시작 (총 5 에폭)")

# 2. YOLOv8n 모델 로드
model = YOLO('yolov8n.pt')

# 3. 학습 실행
results = model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=8,
    project='yolo_quick_run',
    name='pill_detection_nano_final', # 이전 결과와 구분하기 위해 이름 변경
    device=device # 사용 가능한 장치로 지정
)

print("\n✅ YOLOv8 미니 학습 완료!")
print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_final')}")
# Out:
# ✅ Apple M2 GPU (MPS) 사용 가능! 학습 속도가 빠를 수 있습니다.
#
# 데이터 설정 파일 경로: /Users/bellboi/code/codeitteam7/ai05_pill_data.yaml
# 🚀 YOLOv8 모델로 알약 데이터 파인튜닝 시작 (총 5 에폭)
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pill_detection_nano_final2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_final2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 885.7±118.1 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 3.4Mit/s 0.0ss
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1030.0±106.6 MB/s, size: 1701.9 KB)
# val: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 2.1Mit/s 0.0s0s
# Plotting labels to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_final2/labels.jpg...
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_final2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5      2.29G     0.6865       2.16      0.957          2        640: 100% ━━━━━━━━━━━━ 187/187 0.7it/s 4:372.5ss
# WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 1/94 0.0it/s 14.7s<1:15:47WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 2/94 0.1it/s 19.0s<18:17WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 3/94 0.1it/s 23.0s<11:23WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ╸─────────── 4/94 0.2it/s 27.1s<8:60WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 5/94 0.2it/s 31.1s<7:43WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 6/94 0.2it/s 35.3s<7:09WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 7% ╸─────────── 7/94 0.2it/s 39.4s<6:41WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 8/94 0.2it/s 43.5s<6:22WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 9/94 0.2it/s 47.5s<6:07WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 10/94 0.2it/s 51.8s<6:01WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 11/94 0.2it/s 55.9s<5:52WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 12/94 0.2it/s 1:00<5:49WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 13/94 0.2it/s 1:05<5:51WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 14/94 0.2it/s 1:09<5:41WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 15/94 0.2it/s 1:13<5:36WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 16/94 0.2it/s 1:17<5:33WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 17/94 0.2it/s 1:22<5:33WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 19% ━━────────── 18/94 0.2it/s 1:26<5:24WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 19/94 0.2it/s 1:30<5:15WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 21% ━━╸───────── 20/94 0.2it/s 1:34<5:14WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 22% ━━╸───────── 21/94 0.2it/s 1:39<5:18WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 23% ━━╸───────── 22/94 0.2it/s 1:44<5:24WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 24% ━━╸───────── 23/94 0.2it/s 1:48<5:16WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 24/94 0.2it/s 1:53<5:10WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 25/94 0.2it/s 1:57<5:07WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 28% ━━━───────── 26/94 0.2it/s 2:01<5:02WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 27/94 0.2it/s 2:06<4:56WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 30% ━━━╸──────── 28/94 0.2it/s 2:10<4:51WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 31% ━━━╸──────── 29/94 0.2it/s 2:15<4:49WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 30/94 0.2it/s 2:19<4:43WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━╸──────── 31/94 0.2it/s 2:24<4:42WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 34% ━━━━──────── 32/94 0.2it/s 2:28<4:35WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 35% ━━━━──────── 33/94 0.2it/s 2:32<4:27WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 36% ━━━━──────── 34/94 0.2it/s 2:37<4:21WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 35/94 0.2it/s 2:41<4:16WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 38% ━━━━╸─────── 36/94 0.2it/s 2:45<4:12WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 39% ━━━━╸─────── 37/94 0.2it/s 2:50<4:11WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 40% ━━━━╸─────── 38/94 0.2it/s 2:55<4:11WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 41% ━━━━╸─────── 39/94 0.2it/s 2:59<4:07WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 40/94 0.2it/s 3:04<4:07WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 44% ━━━━━─────── 41/94 0.2it/s 3:08<3:54WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 45% ━━━━━─────── 42/94 0.2it/s 3:12<3:45WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 46% ━━━━━─────── 43/94 0.2it/s 3:17<3:44WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 47% ━━━━━╸────── 44/94 0.2it/s 3:21<3:46WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 48% ━━━━━╸────── 45/94 0.2it/s 3:26<3:43WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 49% ━━━━━╸────── 46/94 0.2it/s 3:30<3:36WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 50% ━━━━━━────── 47/94 0.2it/s 3:35<3:35WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 51% ━━━━━━────── 48/94 0.2it/s 3:40<3:27WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 52% ━━━━━━────── 49/94 0.2it/s 3:44<3:25WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 53% ━━━━━━────── 50/94 0.2it/s 3:49<3:18WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 54% ━━━━━━╸───── 51/94 0.2it/s 3:53<3:11WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 55% ━━━━━━╸───── 52/94 0.2it/s 3:58<3:15WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 56% ━━━━━━╸───── 53/94 0.2it/s 4:03<3:17WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 54/94 0.2it/s 4:08<3:10WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 59% ━━━━━━━───── 55/94 0.2it/s 4:12<2:57WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 60% ━━━━━━━───── 56/94 0.2it/s 4:16<2:48WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 61% ━━━━━━━───── 57/94 0.2it/s 4:20<2:41WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 62% ━━━━━━━───── 58/94 0.2it/s 4:25<2:35WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 63% ━━━━━━━╸──── 59/94 0.2it/s 4:29<2:29WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 64% ━━━━━━━╸──── 60/94 0.2it/s 4:33<2:23WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 65% ━━━━━━━╸──── 61/94 0.2it/s 4:37<2:18WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 62/94 0.2it/s 4:41<2:13WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 63/94 0.2it/s 4:45<2:09WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 68% ━━━━━━━━──── 64/94 0.2it/s 4:49<2:04WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 69% ━━━━━━━━──── 65/94 0.2it/s 4:54<2:05WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 70% ━━━━━━━━──── 66/94 0.2it/s 4:59<2:02WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 67/94 0.2it/s 5:03<1:60WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 72% ━━━━━━━━╸─── 68/94 0.2it/s 5:07<1:54WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 73% ━━━━━━━━╸─── 69/94 0.2it/s 5:11<1:47WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 70/94 0.2it/s 5:16<1:44WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 76% ━━━━━━━━━─── 71/94 0.2it/s 5:20<1:37WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 77% ━━━━━━━━━─── 72/94 0.2it/s 5:25<1:35WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 78% ━━━━━━━━━─── 73/94 0.2it/s 5:29<1:32WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 79% ━━━━━━━━━─── 74/94 0.2it/s 5:34<1:31WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 80% ━━━━━━━━━╸── 75/94 0.2it/s 5:38<1:26WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 81% ━━━━━━━━━╸── 76/94 0.2it/s 5:43<1:21WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 82% ━━━━━━━━━╸── 77/94 0.2it/s 5:47<1:16WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 83% ━━━━━━━━━╸── 78/94 0.2it/s 5:52<1:11WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 84% ━━━━━━━━━━── 79/94 0.2it/s 5:56<1:07WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 85% ━━━━━━━━━━── 80/94 0.2it/s 6:01<1:02WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 81/94 0.2it/s 6:05<59.1sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 87% ━━━━━━━━━━── 82/94 0.2it/s 6:10<55.9sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 88% ━━━━━━━━━━╸─ 83/94 0.2it/s 6:15<52.1sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 89% ━━━━━━━━━━╸─ 84/94 0.2it/s 6:20<47.9sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 90% ━━━━━━━━━━╸─ 85/94 0.2it/s 6:25<41.7sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 91% ━━━━━━━━━━╸─ 86/94 0.2it/s 6:29<36.0sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 93% ━━━━━━━━━━━─ 87/94 0.2it/s 6:33<31.2sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 94% ━━━━━━━━━━━─ 88/94 0.2it/s 6:37<26.6sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 95% ━━━━━━━━━━━─ 89/94 0.2it/s 6:42<22.5sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 96% ━━━━━━━━━━━─ 90/94 0.2it/s 6:47<18.5sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 97% ━━━━━━━━━━━╸ 91/94 0.2it/s 6:51<13.3sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 98% ━━━━━━━━━━━╸ 92/94 0.2it/s 6:56<8.9sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 93/94 0.2it/s 7:08<6.4s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 29
#      26 model = YOLO('yolov8n.pt')
#      28 # 3. 학습 실행
# ---> 29 results = model.train(
#      30     data=data_yaml_path,
#      31     epochs=5,
#      32     imgsz=640,
#      33     batch=8,
#      34     project='yolo_quick_run',
#      35     name='pill_detection_nano_final', # 이전 결과와 구분하기 위해 이름 변경
#      36     device=device # 사용 가능한 장치로 지정
#      37 )
#      39 print("\n✅ YOLOv8 미니 학습 완료!")
#      40 print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_final')}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:238, in BaseTrainer.train(self)
#     235         ddp_cleanup(self, str(file))
#     237 else:
# --> 238     self._do_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:473, in BaseTrainer._do_train(self)
#     471 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
#     472     self._clear_memory(threshold=0.5)  # prevent VRAM spike
# --> 473     self.metrics, self.fitness = self.validate()
#     475 # NaN recovery
#     476 if self._handle_nan_recovery(epoch):
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:702, in BaseTrainer.validate(self)
#     700     for buffer in self.ema.ema.buffers():
#     701         dist.broadcast(buffer, src=0)
# --> 702 metrics = self.validator(self)
#     703 if metrics is None:
#     704     return None, None
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/validator.py:220, in BaseValidator.__call__(self, trainer, model)
#     218 with dt[2]:
#     219     if self.training:
# --> 220         self.loss += model.loss(batch, preds)[1]
#     222 # Postprocess
#     223 with dt[3]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:339, in BaseModel.loss(self, batch, preds)
#     337 if preds is None:
#     338     preds = self.forward(batch["img"])
# --> 339 return self.criterion(preds, batch)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:263, in v8DetectionLoss.__call__(self, preds, batch)
#     261 # Targets
#     262 targets = torch.cat((batch["batch_idx"].view(-1, 1), batch["cls"].view(-1, 1), batch["bboxes"]), 1)
# --> 263 targets = self.preprocess(targets, batch_size, scale_tensor=imgsz[[1, 0, 1, 0]])
#     264 gt_labels, gt_bboxes = targets.split((1, 4), 2)  # cls, xyxy
#     265 mask_gt = gt_bboxes.sum(2, keepdim=True).gt_(0.0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:228, in v8DetectionLoss.preprocess(self, targets, batch_size, scale_tensor)
#     226 _, counts = i.unique(return_counts=True)
#     227 counts = counts.to(dtype=torch.int32)
# --> 228 out = torch.zeros(batch_size, counts.max(), ne - 1, device=self.device)
#     229 for j in range(batch_size):
#     230     matches = i == j
#
# RuntimeError: Trying to create tensor with negative dimension -1: [1, -1, 5]

# %%
# @title YOLOv8 알약 데이터 학습 (Batch Size와 Workers 수 조정)
from ultralytics import YOLO
import torch
import os

# 1. 경로 설정 및 장치 확인
data_yaml_path = '/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml'

# MPS (Apple M2) 장치 사용
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f"✅ 사용 가능한 장치: {device.upper()}")

# 2. 모델 로드
# 모델 로드 경로: /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/models/v8
model = YOLO('yolov8n.pt')

# 3. 학습 실행 (파라미터 조정)
# results = model.train(
#     data=data_yaml_path,
#     epochs=5,
#     imgsz=640,
#     # 🚨 Batch Size를 줄여 메모리 부하 감소 (8 -> 4)
#     batch=4,
#     project='yolo_quick_run',
#     name='pill_detection_nano_fix', # 이전 결과와 구분하기 위해 이름 변경
#     device=device,
#     # 🚨 Dataloader Workers 수를 줄여 안정성 확보 (8 -> 0)
#     workers=0,
#     # 🚨 NMS 경고 해결을 위해 평가 주기를 2 에폭마다 1회로 설정
#     # val_interval=2
# )

# @title 배치 크기를 1로 변경하여 다시 시도
model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=1, # 🚨 배치 크기를 1로 줄여 테스트
    project='yolo_quick_run',
    name='pill_detection_nano_batch1_test',
    device=device,
    workers=0,
)

print("\n✅ YOLOv8 학습 재개 완료! (Batch/Workers 조정)")
print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_fix')}")
# Out:
# ✅ 사용 가능한 장치: MPS
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pill_detection_nano_batch1_test, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_test, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 626.5±201.2 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 2.1Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 78.5±13.4 MB/s, size: 1701.9 KB)
# val: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 3.2Mit/s 0.0s0s
# Plotting labels to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_test/labels.jpg...
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_test
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/1489  6.9s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 34
#      15 model = YOLO('yolov8n.pt')
#      17 # 3. 학습 실행 (파라미터 조정)
#      18 # results = model.train(
#      19 #     data=data_yaml_path,
#    (...)
#      32
#      33 # @title 배치 크기를 1로 변경하여 다시 시도
# ---> 34 model.train(
#      35     data=data_yaml_path,
#      36     epochs=5,
#      37     imgsz=640,
#      38     batch=1, # 🚨 배치 크기를 1로 줄여 테스트
#      39     project='yolo_quick_run',
#      40     name='pill_detection_nano_batch1_test',
#      41     device=device,
#      42     workers=0,
#      43 )
#      45 print("\n✅ YOLOv8 학습 재개 완료! (Batch/Workers 조정)")
#      46 print(f"결과 저장 위치: {os.path.join(os.getcwd(), 'yolo_quick_run', 'pill_detection_nano_fix')}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:238, in BaseTrainer.train(self)
#     235         ddp_cleanup(self, str(file))
#     237 else:
# --> 238     self._do_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:422, in BaseTrainer._do_train(self)
#     420     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     421 else:
# --> 422     loss, self.loss_items = self.model(batch)
#     423 self.loss = loss.sum()
#     424 if RANK != -1:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)
#     135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:339, in BaseModel.loss(self, batch, preds)
#     337 if preds is None:
#     338     preds = self.forward(batch["img"])
# --> 339 return self.criterion(preds, batch)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:263, in v8DetectionLoss.__call__(self, preds, batch)
#     261 # Targets
#     262 targets = torch.cat((batch["batch_idx"].view(-1, 1), batch["cls"].view(-1, 1), batch["bboxes"]), 1)
# --> 263 targets = self.preprocess(targets, batch_size, scale_tensor=imgsz[[1, 0, 1, 0]])
#     264 gt_labels, gt_bboxes = targets.split((1, 4), 2)  # cls, xyxy
#     265 mask_gt = gt_bboxes.sum(2, keepdim=True).gt_(0.0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:228, in v8DetectionLoss.preprocess(self, targets, batch_size, scale_tensor)
#     226 _, counts = i.unique(return_counts=True)
#     227 counts = counts.to(dtype=torch.int32)
# --> 228 out = torch.zeros(batch_size, counts.max(), ne - 1, device=self.device)
#     229 for j in range(batch_size):
#     230     matches = i == j
#
# RuntimeError: Trying to create tensor with negative dimension -1: [1, -1, 5]

# %%
# @title 레이블 파일 정리 후 재시도
# @title torch-2.8.0와 MPS 환경에서 발생한 RuntimeError는
# @title 대부분 빈 레이블 파일이나 Dataloader 불안정에서 기인합니다.
# @title 레이블 파일을 정리하고 다시 실행해 보세요.

# 코드의 시작엔 # @title 을 꼭 붙여줘.

import torch
import os
from ultralytics import YOLO

# MPS 장치 설정 (이미 활성화됨)
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
data_yaml_path = '/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml'

print(f"✅ 사용 가능한 장치: {device.upper()}")

# 1. 모델 로드
# 모델이 이미 로드되어 있다고 가정합니다. (yolov8n.pt)
model = YOLO('yolov8n.pt')

# 2. 학습 실행 (배치 크기 1 유지, workers 0 유지)
# 데이터셋 클리닝이 필요합니다.
results = model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=1, # 배치 크기를 1로 유지하여 문제 추적 용이
    project='yolo_quick_run',
    name='pill_detection_nano_batch1_fix_clean', # 이름 변경
    device=device,
    workers=0, # Dataloader 안정성 확보
    # cache='disk' # 데이터 로딩 안정화를 위해 캐시 사용 고려
)
# Out:
# ✅ 사용 가능한 장치: MPS
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pill_detection_nano_batch1_fix_clean, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_fix_clean, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1039.5±188.1 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 3.4Mit/s 0.0ss
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1076.3±122.5 MB/s, size: 1701.9 KB)
# val: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1489 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1489/1489 3.2Mit/s 0.0s0s
# Plotting labels to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_fix_clean/labels.jpg...
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch1_fix_clean
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/1489  1.0s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 24
#      20 model = YOLO('yolov8n.pt')
#      22 # 2. 학습 실행 (배치 크기 1 유지, workers 0 유지)
#      23 # 데이터셋 클리닝이 필요합니다.
# ---> 24 results = model.train(
#      25     data=data_yaml_path,
#      26     epochs=5,
#      27     imgsz=640,
#      28     batch=1, # 배치 크기를 1로 유지하여 문제 추적 용이
#      29     project='yolo_quick_run',
#      30     name='pill_detection_nano_batch1_fix_clean', # 이름 변경
#      31     device=device,
#      32     workers=0, # Dataloader 안정성 확보
#      33     # cache='disk' # 데이터 로딩 안정화를 위해 캐시 사용 고려
#      34 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:238, in BaseTrainer.train(self)
#     235         ddp_cleanup(self, str(file))
#     237 else:
# --> 238     self._do_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:422, in BaseTrainer._do_train(self)
#     420     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     421 else:
# --> 422     loss, self.loss_items = self.model(batch)
#     423 self.loss = loss.sum()
#     424 if RANK != -1:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)
#     135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:339, in BaseModel.loss(self, batch, preds)
#     337 if preds is None:
#     338     preds = self.forward(batch["img"])
# --> 339 return self.criterion(preds, batch)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:263, in v8DetectionLoss.__call__(self, preds, batch)
#     261 # Targets
#     262 targets = torch.cat((batch["batch_idx"].view(-1, 1), batch["cls"].view(-1, 1), batch["bboxes"]), 1)
# --> 263 targets = self.preprocess(targets, batch_size, scale_tensor=imgsz[[1, 0, 1, 0]])
#     264 gt_labels, gt_bboxes = targets.split((1, 4), 2)  # cls, xyxy
#     265 mask_gt = gt_bboxes.sum(2, keepdim=True).gt_(0.0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:228, in v8DetectionLoss.preprocess(self, targets, batch_size, scale_tensor)
#     226 _, counts = i.unique(return_counts=True)
#     227 counts = counts.to(dtype=torch.int32)
# --> 228 out = torch.zeros(batch_size, counts.max(), ne - 1, device=self.device)
#     229 for j in range(batch_size):
#     230     matches = i == j
#
# RuntimeError: Trying to create tensor with negative dimension -1: [1, -1, 5]

# %%
# @title 빈 레이블 파일 클리닝 스크립트

import os

# ⚠️ 사용자 경로에 맞게 이 경로를 반드시 수정하세요!
labels_dir = '/Users/bellboi/data/ai05-level1-project/labels'
# 만약 레이블이 images 폴더와 같은 레벨에 있다면, 경로는 '/Users/bellboi/data/ai05-level1-project/labels' 일 것입니다.
# 정확한 labels 폴더 경로를 확인하고 수정해 주세요.

if not os.path.isdir(labels_dir):
    print(f"❌ 오류: 레이블 디렉토리 '{labels_dir}'를 찾을 수 없습니다. 경로를 확인해주세요.")
else:
    print(f"🔍 '{labels_dir}'에서 빈 레이블 파일 검색 시작...")

    empty_files = []

    # 디렉토리 내 모든 .txt 파일을 검사
    for filename in os.listdir(labels_dir):
        if filename.endswith('.txt'):
            filepath = os.path.join(labels_dir, filename)

            # 파일 크기가 0이거나, 크기가 0이 아니더라도 내용이 공백만 있는 경우
            if os.path.getsize(filepath) == 0:
                is_empty = True
            else:
                with open(filepath, 'r') as f:
                    content = f.read().strip()
                    is_empty = not content

            if is_empty:
                empty_files.append(filepath)

    if empty_files:
        print(f"\n🚨 빈 레이블 파일 {len(empty_files)}개를 발견했습니다. 자동으로 제거합니다.")

        for filepath in empty_files:
            try:
                # 1. 빈 레이블 파일 제거
                os.remove(filepath)
                print(f"   🗑️ 제거된 레이블: {filepath}")

                # 2. 대응되는 이미지 파일도 제거 (선택 사항이지만 권장)
                # YOLO 포맷은 .txt 파일명과 .jpg 파일명이 같습니다. 확장자만 변경하여 제거
                base_name = os.path.splitext(filepath)[0]

                # 이미지 파일 경로 추정 (경로 구조에 따라 다를 수 있음. 예: labels 대신 images 폴더)
                # users/data/ai05-level1-project/labels/img1.txt -> users/data/ai05-level1-project/images/img1.jpg
                # 정확한 이미지 폴더 경로를 모르면 이 부분은 주석 처리하고 수동으로 제거

                # 예시: 'labels'를 'images'로 대체
                image_filepath_jpg = base_name.replace('labels', 'images') + '.jpg'
                image_filepath_png = base_name.replace('labels', 'images') + '.png'

                if os.path.exists(image_filepath_jpg):
                    os.remove(image_filepath_jpg)
                    print(f"   🗑️ 제거된 이미지: {image_filepath_jpg}")
                elif os.path.exists(image_filepath_png):
                    os.remove(image_filepath_png)
                    print(f"   🗑️ 제거된 이미지: {image_filepath_png}")

            except Exception as e:
                print(f"   ❌ 제거 실패 ({filepath}): {e}")

        print("\n✅ 빈 레이블 파일 및 대응되는 이미지(추정) 제거 완료. 학습을 다시 시도해 주세요.")
        print("💡 참고: YOLOv8이 레이블 캐시 파일을 재생성하도록 **`.cache` 파일을 삭제** 후 학습을 시작하세요.")

    else:
        print("\n✅ 빈 레이블 파일이 발견되지 않았습니다. 데이터셋은 깨끗합니다.")
        print("💡 그럼에도 오류가 발생한다면, Ultralytics/PyTorch/MPS **버전 문제**이거나 특정 이미지 데이터 자체의 로딩 문제입니다.")
        print("   다음 해결책(3. Dataloader 옵션 조정)을 시도해 보세요.")
# Out:
# 🔍 '/Users/bellboi/data/ai05-level1-project/labels'에서 빈 레이블 파일 검색 시작...
#
# 🚨 빈 레이블 파일 1개를 발견했습니다. 자동으로 제거합니다.
#    🗑️ 제거된 레이블: /Users/bellboi/data/ai05-level1-project/labels/K-003544-004543-012247-016551_0_2_0_2_70_000_200.txt
#    🗑️ 제거된 이미지: /Users/bellboi/data/ai05-level1-project/images/K-003544-004543-012247-016551_0_2_0_2_70_000_200.png
#
# ✅ 빈 레이블 파일 및 대응되는 이미지(추정) 제거 완료. 학습을 다시 시도해 주세요.
# 💡 참고: YOLOv8이 레이블 캐시 파일을 재생성하도록 **`.cache` 파일을 삭제** 후 학습을 시작하세요.

# %%
 # @title 데이터셋 클리닝 완료 후 YOLOv8 학습 재개
# 코드의 시작엔 # @title 을 꼭 붙여줘.

import torch
from ultralytics import YOLO

# MPS 장치 설정 (이미 활성화됨)
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
data_yaml_path = '/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml'

print(f"✅ 사용 가능한 장치: {device.upper()}")

# 1. 모델 로드
model = YOLO('yolov8n.pt')

# 2. 학습 실행
# 'cache=ram' 또는 'cache=disk' 옵션을 사용하여 데이터 로딩 안정성을 높이는 것을 권장합니다.
# 데이터 클리닝을 했다는 가정 하에 batch=4로 늘려보겠습니다. (Batch=1에서 문제의 이미지를 제거했기를 기대)
results = model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=4, # 클린 후, 배치 사이즈를 다시 4로 시도
    project='yolo_quick_run',
    name='pill_detection_nano_batch4_clean_final',
    device=device,
    workers=0,
    cache='disk', # 데이터 로딩 안정화 옵션 추가
)

print("\n🎉 학습 재개 완료. 이제 Empty Label 문제가 해결되었기를 바랍니다.")
# Out:
# ✅ 사용 가능한 장치: MPS
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pill_detection_nano_batch4_clean_final, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_clean_final, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1061.5±180.1 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels... 1488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1488/1488 708.8it/s 2.1s0.1s
# train: New cache created: /Users/bellboi/data/ai05-level1-project/labels.cache
# train: Caching images (5.2GB Disk): 100% ━━━━━━━━━━━━ 1488/1488 128.9it/s 11.5s0.1s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 849.5±298.9 MB/s, size: 1780.0 KB)
# val: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1488/1488 4.2Mit/s 0.0s0s
# val: Caching images (5.2GB Disk): 100% ━━━━━━━━━━━━ 1488/1488 75.7Kit/s 0.0s
# Plotting labels to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_clean_final/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_clean_final
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
#         1/5      2.53G     0.6673       2.22     0.9569          6        640: 84% ━━━━━━━━━━── 311/372 2.2it/s 4:58<27.8s
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 19
#      14 model = YOLO('yolov8n.pt')
#      16 # 2. 학습 실행
#      17 # 'cache=ram' 또는 'cache=disk' 옵션을 사용하여 데이터 로딩 안정성을 높이는 것을 권장합니다.
#      18 # 데이터 클리닝을 했다는 가정 하에 batch=4로 늘려보겠습니다. (Batch=1에서 문제의 이미지를 제거했기를 기대)
# ---> 19 results = model.train(
#      20     data=data_yaml_path,
#      21     epochs=5,
#      22     imgsz=640,
#      23     batch=4, # 클린 후, 배치 사이즈를 다시 4로 시도
#      24     project='yolo_quick_run',
#      25     name='pill_detection_nano_batch4_clean_final',
#      26     device=device,
#      27     workers=0,
#      28     cache='disk', # 데이터 로딩 안정화 옵션 추가
#      29 )
#      31 print("\n🎉 학습 재개 완료. 이제 Empty Label 문제가 해결되었기를 바랍니다.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:238, in BaseTrainer.train(self)
#     235         ddp_cleanup(self, str(file))
#     237 else:
# --> 238     self._do_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/trainer.py:422, in BaseTrainer._do_train(self)
#     420     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     421 else:
# --> 422     loss, self.loss_items = self.model(batch)
#     423 self.loss = loss.sum()
#     424 if RANK != -1:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)
#     135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:339, in BaseModel.loss(self, batch, preds)
#     337 if preds is None:
#     338     preds = self.forward(batch["img"])
# --> 339 return self.criterion(preds, batch)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:263, in v8DetectionLoss.__call__(self, preds, batch)
#     261 # Targets
#     262 targets = torch.cat((batch["batch_idx"].view(-1, 1), batch["cls"].view(-1, 1), batch["bboxes"]), 1)
# --> 263 targets = self.preprocess(targets, batch_size, scale_tensor=imgsz[[1, 0, 1, 0]])
#     264 gt_labels, gt_bboxes = targets.split((1, 4), 2)  # cls, xyxy
#     265 mask_gt = gt_bboxes.sum(2, keepdim=True).gt_(0.0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/loss.py:228, in v8DetectionLoss.preprocess(self, targets, batch_size, scale_tensor)
#     226 _, counts = i.unique(return_counts=True)
#     227 counts = counts.to(dtype=torch.int32)
# --> 228 out = torch.zeros(batch_size, counts.max(), ne - 1, device=self.device)
#     229 for j in range(batch_size):
#     230     matches = i == j
#
# RuntimeError: Trying to create tensor with negative dimension -1: [4, -1, 5]

# %%
# @title MPS 안정화 및 모자이크 증강 비활성화 후 YOLOv8 학습 재개
# 코드의 시작엔 # @title 을 꼭 붙여줘.

import torch
from ultralytics import YOLO

# MPS 장치 설정 (Apple M2)
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
data_yaml_path = '/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml'

print(f"✅ 사용 가능한 장치: {device.upper()}")
print(f"⚠️ MPS 환경의 불안정성 해결을 위해 'mosaic=0.0', 'workers=0'로 설정합니다.")

# 1. 모델 로드
model = YOLO('yolov8n.pt')

# 2. 학습 실행 (MPS 안정화 옵션 적용)
# batch=4는 유지합니다.
results = model.train(
    data=data_yaml_path,
    epochs=5,
    imgsz=640,
    batch=4,
    project='yolo_quick_run',
    name='pill_detection_nano_batch4_no_mosaic', # 이름 변경
    device=device,
    workers=0,
    cache='disk', # 데이터 로딩 안정화 유지
    # 💥 핵심 변경 사항: 모자이크 증강 비활성화
    mosaic=0.0,
)

print("\n🎉 모자이크 증강을 비활성화한 후 학습을 다시 시도했습니다. MPS 충돌 문제가 해결되었기를 바랍니다.")
# Out:
# ✅ 사용 가능한 장치: MPS
# ⚠️ MPS 환경의 불안정성 해결을 위해 'mosaic=0.0', 'workers=0'로 설정합니다.
# Ultralytics 8.3.220 🚀 Python-3.9.6 torch-2.8.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/bellboi/code/codeitteam7/ai05_pill_data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=pill_detection_nano_batch4_no_mosaic, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_quick_run, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_no_mosaic, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 655.7±472.0 MB/s, size: 1738.9 KB)
# train: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1488/1488 3.3Mit/s 0.0s0s
# train: Caching images (5.2GB Disk): 100% ━━━━━━━━━━━━ 1488/1488 94.2Kit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1862.0±2322.2 MB/s, size: 1780.0 KB)
# val: Scanning /Users/bellboi/data/ai05-level1-project/labels.cache... 1488 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1488/1488 5.3Mit/s 0.0s
# val: Caching images (5.2GB Disk): 100% ━━━━━━━━━━━━ 1488/1488 72.7Kit/s 0.0s
# Plotting labels to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_no_mosaic/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/bellboi/code/codeitteam7/yolo_quick_run/pill_detection_nano_batch4_no_mosaic
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
# /Users/bellboi/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/plotting.py:627: UserWarning: Glyph 50557 (\N{HANGUL SYLLABLE YAG}) missing from font(s) DejaVu Sans.
#   plt.savefig(fname, dpi=200)
#         1/5      2.53G     0.5578      2.391       0.86          4        640: 100% ━━━━━━━━━━━━ 372/372 0.9it/s 7:16<0.9s
# WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 1/186 0.0it/s 17.3s<2:58:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 2/186 0.1it/s 21.1s<33:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 3/186 0.1it/s 25.5s<23:07WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 4/186 0.2it/s 29.3s<17:43WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 5/186 0.2it/s 32.7s<14:24WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 6/186 0.2it/s 36.7s<13:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ──────────── 7/186 0.2it/s 40.3s<12:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ╸─────────── 8/186 0.2it/s 44.1s<12:08WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 9/186 0.3it/s 47.7s<11:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 10/186 0.3it/s 51.4s<11:13WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 11/186 0.3it/s 55.3s<11:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 12/186 0.3it/s 59.2s<11:13WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 7% ╸─────────── 13/186 0.3it/s 1:03<10:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 15/186 0.3it/s 1:10<10:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 16/186 0.3it/s 1:14<10:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 17/186 0.3it/s 1:17<10:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 18/186 0.3it/s 1:22<10:34WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 19/186 0.3it/s 1:26<10:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 20/186 0.3it/s 1:29<10:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 21/186 0.3it/s 1:33<10:31WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 22/186 0.3it/s 1:37<10:27WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 23/186 0.3it/s 1:41<10:37WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 24/186 0.2it/s 1:48<12:11WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 25/186 0.2it/s 1:57<14:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 26/186 0.2it/s 2:06<16:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 27/186 0.2it/s 2:11<14:27WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 28/186 0.2it/s 2:16<14:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 29/186 0.2it/s 2:19<12:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 30/186 0.2it/s 2:25<12:44WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 31/186 0.2it/s 2:29<12:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 32/186 0.2it/s 2:34<12:02WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 33/186 0.2it/s 2:38<11:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 34/186 0.2it/s 2:43<11:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 19% ━━────────── 36/186 0.3it/s 2:49<8:599WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 37/186 0.3it/s 2:53<9:23WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 38/186 0.3it/s 2:58<9:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 21% ━━╸───────── 39/186 0.2it/s 3:04<10:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 22% ━━╸───────── 40/186 0.2it/s 3:10<11:42WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 22% ━━╸───────── 41/186 0.2it/s 3:14<10:45WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 23% ━━╸───────── 43/186 0.2it/s 3:24<11:19WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 24% ━━╸───────── 44/186 0.2it/s 3:28<11:04WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 24% ━━╸───────── 45/186 0.2it/s 3:37<12:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━╸───────── 46/186 0.2it/s 3:43<12:57WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━━───────── 47/186 0.2it/s 3:50<13:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 48/186 0.2it/s 3:56<13:38WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 49/186 0.2it/s 4:03<13:57WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 50/186 0.2it/s 4:07<11:57WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 28% ━━━───────── 52/186 0.2it/s 4:17<11:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 28% ━━━───────── 53/186 0.2it/s 4:22<11:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 54/186 0.2it/s 4:27<11:16WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 30% ━━━╸──────── 55/186 0.2it/s 4:31<9:57WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 30% ━━━╸──────── 56/186 0.2it/s 4:36<10:16WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 31% ━━━╸──────── 58/186 0.2it/s 4:45<9:584WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 59/186 0.2it/s 4:51<10:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━╸──────── 61/186 0.2it/s 4:60<9:080WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 62/186 0.2it/s 5:05<9:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 34% ━━━━──────── 64/186 0.2it/s 5:14<9:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 35% ━━━━──────── 65/186 0.2it/s 5:20<9:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 35% ━━━━──────── 66/186 0.2it/s 5:24<9:20WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 36% ━━━━──────── 67/186 0.2it/s 5:29<9:36WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 68/186 0.2it/s 5:34<9:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 69/186 0.2it/s 5:38<8:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 38% ━━━━╸─────── 70/186 0.2it/s 5:42<8:03WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 38% ━━━━╸─────── 71/186 0.2it/s 5:46<8:12WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 40% ━━━━╸─────── 75/186 0.3it/s 6:02<7:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 42% ━━━━━─────── 78/186 0.3it/s 6:11<5:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 42% ━━━━━─────── 79/186 0.3it/s 6:16<6:03WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 80/186 0.3it/s 6:21<6:36WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 44% ━━━━━─────── 81/186 0.2it/s 6:26<7:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 44% ━━━━━─────── 82/186 0.2it/s 6:31<7:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 45% ━━━━━─────── 83/186 0.2it/s 6:35<7:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 45% ━━━━━─────── 84/186 0.2it/s 6:40<7:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 46% ━━━━━─────── 85/186 0.2it/s 6:44<7:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 46% ━━━━━╸────── 86/186 0.2it/s 6:49<7:37WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 47% ━━━━━╸────── 88/186 0.2it/s 6:59<7:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 49% ━━━━━╸────── 92/186 0.3it/s 7:15<6:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 50% ━━━━━━────── 93/186 0.3it/s 7:19<6:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 54% ━━━━━━╸───── 101/186 0.3it/s 7:50<5:03WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 55% ━━━━━━╸───── 102/186 0.3it/s 7:55<5:33WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 56% ━━━━━━╸───── 104/186 0.2it/s 8:04<5:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 58% ━━━━━━╸───── 108/186 0.3it/s 8:18<3:54WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 59% ━━━━━━━───── 109/186 0.3it/s 8:23<4:21WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 59% ━━━━━━━───── 110/186 0.3it/s 8:28<4:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 60% ━━━━━━━───── 111/186 0.2it/s 8:33<5:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 63% ━━━━━━━╸──── 118/186 0.3it/s 8:58<4:00WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 65% ━━━━━━━╸──── 120/186 0.3it/s 9:05<3:38WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 65% ━━━━━━━╸──── 121/186 0.3it/s 9:10<4:02WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 122/186 0.3it/s 9:14<4:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 123/186 0.2it/s 9:20<4:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 68% ━━━━━━━━──── 127/186 0.3it/s 9:37<3:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 70% ━━━━━━━━──── 130/186 0.3it/s 9:50<3:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 73% ━━━━━━━━╸─── 135/186 0.3it/s 10:08<2:60WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 137/186 0.3it/s 10:17<2:59WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 76% ━━━━━━━━━─── 142/186 0.3it/s 10:36<2:43WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 77% ━━━━━━━━━─── 143/186 0.3it/s 10:39<2:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 77% ━━━━━━━━━─── 144/186 0.3it/s 10:44<2:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 78% ━━━━━━━━━─── 145/186 0.2it/s 10:49<2:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 80% ━━━━━━━━━╸── 148/186 0.3it/s 11:00<2:26WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 80% ━━━━━━━━━╸── 149/186 0.3it/s 11:04<2:24WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 81% ━━━━━━━━━╸── 151/186 0.2it/s 11:14<2:26WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 82% ━━━━━━━━━╸── 152/186 0.2it/s 11:18<2:27WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 82% ━━━━━━━━━╸── 153/186 0.2it/s 11:23<2:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 83% ━━━━━━━━━╸── 154/186 0.3it/s 11:26<2:01WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 83% ━━━━━━━━━━── 155/186 0.2it/s 11:30<2:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 84% ━━━━━━━━━━── 157/186 0.3it/s 11:38<1:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 85% ━━━━━━━━━━── 158/186 0.2it/s 11:44<2:00WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 85% ━━━━━━━━━━── 159/186 0.2it/s 11:48<1:59WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 87% ━━━━━━━━━━── 161/186 0.2it/s 11:56<1:42WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 89% ━━━━━━━━━━╸─ 165/186 0.3it/s 12:08<1:07WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 93% ━━━━━━━━━━━─ 173/186 0.3it/s 12:38<40.3sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 94% ━━━━━━━━━━━─ 174/186 0.3it/s 12:45<44.5sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 96% ━━━━━━━━━━━─ 178/186 0.3it/s 13:00<28.2sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 184/186 0.4it/s 13:19<5.0ssWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 99% ━━━━━━━━━━━╸ 185/186 0.3it/s 13:24<2.9sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 186/186 0.2it/s 13:27
#                    all       1488       1488      0.469      0.493      0.439       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5       2.5G      0.527      1.692     0.8459          4        640: 100% ━━━━━━━━━━━━ 372/372 0.3it/s 18:24<0.9s
# WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 1/186 0.0it/s 6.8s<1:09:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 2/186 0.1it/s 10.0s<24:38WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 3/186 0.1it/s 17.8s<24:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 4/186 0.2it/s 21.7s<18:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 5/186 0.2it/s 26.3s<16:43WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 6/186 0.2it/s 33.7s<17:57WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ──────────── 7/186 0.2it/s 41.2s<19:04WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ╸─────────── 8/186 0.2it/s 47.5s<18:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 9/186 0.2it/s 52.0s<16:42WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 10/186 0.2it/s 57.8s<16:40WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 11/186 0.2it/s 1:02<15:34WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 12/186 0.2it/s 1:10<16:56WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 7% ╸─────────── 13/186 0.2it/s 1:13<13:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 14/186 0.2it/s 1:18<13:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 15/186 0.2it/s 1:24<14:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 16/186 0.2it/s 1:30<14:44WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 17/186 0.2it/s 1:36<15:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 18/186 0.2it/s 1:42<15:45WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 19/186 0.2it/s 1:48<16:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 20/186 0.2it/s 1:53<14:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 21/186 0.2it/s 1:58<14:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 22/186 0.2it/s 2:03<14:19WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 23/186 0.2it/s 2:07<13:24WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 24/186 0.2it/s 2:11<12:12WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 25/186 0.2it/s 2:17<13:03WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 26/186 0.2it/s 2:22<13:12WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 27/186 0.2it/s 2:25<11:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 28/186 0.3it/s 2:29<10:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 29/186 0.2it/s 2:34<10:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 30/186 0.2it/s 2:39<11:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 31/186 0.2it/s 2:43<11:39WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 32/186 0.2it/s 2:48<11:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 33/186 0.2it/s 2:53<11:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 34/186 0.2it/s 2:58<12:09WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 19% ━━────────── 35/186 0.2it/s 3:03<12:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 37/186 0.3it/s 3:10<9:224WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 38/186 0.2it/s 3:15<10:04WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 21% ━━╸───────── 39/186 0.3it/s 3:18<9:24WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 22% ━━╸───────── 40/186 0.3it/s 3:21<8:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 24% ━━╸───────── 44/186 0.4it/s 3:31<5:40WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 24% ━━╸───────── 45/186 0.4it/s 3:36<6:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━╸───────── 46/186 0.3it/s 3:40<7:16WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━━───────── 47/186 0.3it/s 3:45<7:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 48/186 0.3it/s 3:49<8:27WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 49/186 0.2it/s 3:55<9:34WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 50/186 0.2it/s 4:00<9:59WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 51/186 0.2it/s 4:04<9:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 28% ━━━───────── 52/186 0.2it/s 4:08<9:13WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 54/186 0.2it/s 4:18<9:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 30% ━━━╸──────── 55/186 0.2it/s 4:23<10:03WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 31% ━━━╸──────── 57/186 0.3it/s 4:29<7:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 31% ━━━╸──────── 58/186 0.2it/s 4:36<8:42WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 59/186 0.2it/s 4:40<8:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 60/186 0.3it/s 4:44<7:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━╸──────── 61/186 0.3it/s 4:47<7:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 62/186 0.3it/s 4:51<7:45WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 34% ━━━━──────── 63/186 0.3it/s 4:54<7:16WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 35% ━━━━──────── 65/186 0.4it/s 4:59<5:09WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 69/186 0.6it/s 5:08<3:19WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 38% ━━━━╸─────── 70/186 0.5it/s 5:12<3:50WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 38% ━━━━╸─────── 71/186 0.4it/s 5:17<4:39WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 39% ━━━━╸─────── 72/186 0.3it/s 5:22<5:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 41% ━━━━╸─────── 76/186 0.4it/s 5:32<4:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 45% ━━━━━─────── 84/186 0.7it/s 5:54<2:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 50% ━━━━━━────── 93/186 0.5it/s 6:16<3:12WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 51% ━━━━━━────── 94/186 0.4it/s 6:20<3:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 51% ━━━━━━────── 95/186 0.3it/s 6:25<4:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 52% ━━━━━━────── 96/186 0.3it/s 6:29<4:37WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 52% ━━━━━━────── 97/186 0.3it/s 6:33<5:01WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 53% ━━━━━━────── 98/186 0.3it/s 6:37<5:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 53% ━━━━━━────── 99/186 0.3it/s 6:42<5:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 54% ━━━━━━╸───── 101/186 0.4it/s 6:46<3:27WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 55% ━━━━━━╸───── 102/186 0.4it/s 6:50<3:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 56% ━━━━━━╸───── 104/186 0.4it/s 6:55<3:40WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 56% ━━━━━━╸───── 105/186 0.4it/s 6:58<3:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 106/186 0.3it/s 7:02<3:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 58% ━━━━━━╸───── 107/186 0.3it/s 7:05<3:53WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 58% ━━━━━━╸───── 108/186 0.3it/s 7:10<4:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 59% ━━━━━━━───── 109/186 0.2it/s 7:18<5:16WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 60% ━━━━━━━───── 111/186 0.3it/s 7:25<4:11WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 60% ━━━━━━━───── 112/186 0.3it/s 7:28<4:13WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 61% ━━━━━━━───── 113/186 0.3it/s 7:32<4:13WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 123/186 0.7it/s 7:52<1:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 124/186 0.6it/s 7:56<1:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 88% ━━━━━━━━━━╸─ 163/186 0.7it/s 9:00<31.0sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 91% ━━━━━━━━━━╸─ 170/186 0.6it/s 9:15<28.9sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 186/186 0.3it/s 9:441.9ss
#                    all       1488       1488       0.47      0.527      0.373      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      2.51G     0.4683      1.395     0.8325          4        640: 100% ━━━━━━━━━━━━ 372/372 0.6it/s 11:00<0.5s
# WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 1/186 0.1it/s 4.1s<41:58WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 2/186 0.1it/s 8.1s<24:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 3/186 0.1it/s 14.2s<22:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 4/186 0.2it/s 18.8s<18:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 5/186 0.2it/s 23.5s<17:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 6/186 0.2it/s 28.5s<16:23WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ──────────── 7/186 0.2it/s 34.5s<16:43WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ╸─────────── 8/186 0.2it/s 37.4s<13:04WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 9/186 0.2it/s 41.0s<12:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 10/186 0.3it/s 44.0s<10:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 11/186 0.3it/s 47.7s<10:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 12/186 0.3it/s 52.6s<11:36WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 7% ╸─────────── 13/186 0.2it/s 56.8s<11:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 14/186 0.3it/s 1:01<11:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 15/186 0.3it/s 1:05<11:20WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 16/186 0.2it/s 1:10<12:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 17/186 0.2it/s 1:14<11:39WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 18/186 0.2it/s 1:18<12:07WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 19/186 0.2it/s 1:22<11:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 20/186 0.2it/s 1:26<11:21WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 21/186 0.3it/s 1:29<9:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 22/186 0.3it/s 1:32<9:01WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 23/186 0.3it/s 1:36<9:23WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 25/186 0.3it/s 1:42<8:37WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 26/186 0.3it/s 1:46<9:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 28/186 0.3it/s 1:55<9:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 29/186 0.3it/s 1:58<8:54WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 30/186 0.3it/s 2:00<8:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 31/186 0.3it/s 2:04<8:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 33/186 0.3it/s 2:13<9:41WARNING ⚠️ NMS time limit 2.400s exceeded
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 56% ━━━━━━╸───── 105/186 0.5it/s 4:38<2:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 106/186 0.4it/s 4:41<3:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 62% ━━━━━━━───── 115/186 0.8it/s 4:59<1:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 122/186 1.0it/s 5:09<1:02WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 124/186 0.7it/s 5:16<1:30WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 137/186 0.7it/s 5:34<1:08sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 138/186 0.6it/s 5:37<1:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 75% ━━━━━━━━╸─── 139/186 0.5it/s 5:39<1:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 186/186 0.5it/s 6:331.0ss
#                    all       1488       1488      0.496      0.673      0.509      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5      2.49G     0.4272      1.226      0.823          4        640: 100% ━━━━━━━━━━━━ 372/372 1.0it/s 6:28<0.4s
# WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 1/186 0.1it/s 5.7s<58:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 1% ──────────── 2/186 0.1it/s 11.8s<35:36WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 3/186 0.1it/s 16.7s<24:60WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 2% ──────────── 4/186 0.2it/s 21.1s<19:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 5/186 0.2it/s 25.7s<17:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 3% ──────────── 6/186 0.2it/s 30.7s<16:38WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ──────────── 7/186 0.2it/s 35.5s<15:45WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 4% ╸─────────── 8/186 0.2it/s 41.7s<16:23WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 9/186 0.2it/s 47.0s<16:10WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 5% ╸─────────── 10/186 0.2it/s 51.4s<14:58WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 11/186 0.2it/s 55.9s<14:14WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 6% ╸─────────── 12/186 0.2it/s 1:01<14:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 7% ╸─────────── 13/186 0.2it/s 1:07<14:53WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 14/186 0.2it/s 1:12<14:60WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 8% ╸─────────── 15/186 0.2it/s 1:16<13:49WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 16/186 0.2it/s 1:22<14:11WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 9% ━─────────── 17/186 0.2it/s 1:26<13:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 18/186 0.2it/s 1:31<13:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 10% ━─────────── 19/186 0.2it/s 1:37<14:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 20/186 0.2it/s 1:42<13:21WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 11% ━─────────── 21/186 0.2it/s 1:46<12:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 22/186 0.2it/s 1:50<12:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 12% ━─────────── 23/186 0.3it/s 1:53<10:45WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 24/186 0.2it/s 1:58<11:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 13% ━╸────────── 25/186 0.2it/s 2:03<11:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 26/186 0.2it/s 2:08<12:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 27/186 0.3it/s 2:11<10:36WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 28/186 0.2it/s 2:17<11:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 29/186 0.2it/s 2:21<11:17WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 16% ━╸────────── 30/186 0.3it/s 2:24<10:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 31/186 0.2it/s 2:29<10:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 17% ━━────────── 32/186 0.2it/s 2:35<11:31WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 18% ━━────────── 33/186 0.2it/s 2:38<10:28WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 19% ━━────────── 35/186 0.3it/s 2:45<9:029WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 19% ━━────────── 36/186 0.3it/s 2:49<9:25WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 37/186 0.3it/s 2:54<9:48WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 20% ━━────────── 38/186 0.3it/s 2:57<9:31WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 23% ━━╸───────── 42/186 0.3it/s 3:09<6:56WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━╸───────── 46/186 0.6it/s 3:18<3:51WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 26% ━━━───────── 48/186 0.5it/s 3:25<4:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 50/186 0.4it/s 3:32<5:59WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 27% ━━━───────── 51/186 0.3it/s 3:37<6:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 28% ━━━───────── 52/186 0.3it/s 3:42<7:34WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 54/186 0.3it/s 3:49<7:39WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 30% ━━━╸──────── 56/186 0.4it/s 3:55<4:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 59/186 0.5it/s 4:02<4:20WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 32% ━━━╸──────── 60/186 0.4it/s 4:05<4:47WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━╸──────── 61/186 0.4it/s 4:08<5:06WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 62/186 0.4it/s 4:12<5:38WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 34% ━━━━──────── 63/186 0.3it/s 4:20<6:55WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 35% ━━━━──────── 65/186 0.4it/s 4:25<5:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 36% ━━━━──────── 67/186 0.3it/s 4:31<5:58WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 68/186 0.3it/s 4:36<6:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 37% ━━━━──────── 69/186 0.3it/s 4:43<7:43WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 39% ━━━━╸─────── 72/186 0.3it/s 4:55<6:29WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 44% ━━━━━─────── 81/186 0.5it/s 5:17<3:32WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 50% ━━━━━━────── 93/186 0.7it/s 5:37<2:05WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 51% ━━━━━━────── 94/186 0.6it/s 5:43<2:41WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 53% ━━━━━━────── 99/186 0.6it/s 21:07<2:33WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 61% ━━━━━━━───── 114/186 0.5it/s 21:45<2:15WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 65% ━━━━━━━╸──── 121/186 0.6it/s 38:18<1:42WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 122/186 0.6it/s 38:21<1:56WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 66% ━━━━━━━╸──── 123/186 0.5it/s 38:25<2:18WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 68% ━━━━━━━━──── 126/186 0.6it/s 38:31<1:37WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 73% ━━━━━━━━╸─── 135/186 0.6it/s 38:48<1:22WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 138/186 0.5it/s 38:55<1:34WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 75% ━━━━━━━━╸─── 139/186 0.4it/s 38:60<1:52WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 75% ━━━━━━━━━─── 140/186 0.4it/s 39:04<2:04WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 76% ━━━━━━━━━─── 142/186 0.4it/s 39:09<1:40WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 77% ━━━━━━━━━─── 143/186 0.4it/s 39:15<1:59WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 77% ━━━━━━━━━─── 144/186 0.3it/s 39:19<2:11WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 78% ━━━━━━━━━─── 146/186 0.3it/s 39:25<1:60WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 80% ━━━━━━━━━╸── 149/186 0.4it/s 39:34<1:35WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 81% ━━━━━━━━━╸── 151/186 0.3it/s 55:54<1:46WARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 83% ━━━━━━━━━━── 155/186 0.6it/s 56:02<56.2sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 94% ━━━━━━━━━━━─ 174/186 0.8it/s 56:35<15.9sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 95% ━━━━━━━━━━━─ 176/186 0.5it/s 1:13:35<21.0sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 97% ━━━━━━━━━━━╸ 181/186 0.6it/s 1:13:45<9.0ssWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 186/186 0.0it/s 1:13:561.7s
#                    all       1488       1488       0.52      0.619       0.51      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      2.51G     0.3898      1.173     0.8116          4        640: 4% ──────────── 15/372 0.7it/s 12:22<8:07
